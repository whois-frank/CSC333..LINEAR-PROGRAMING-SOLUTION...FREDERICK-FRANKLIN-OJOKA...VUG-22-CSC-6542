# %%
 import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linprog

def plot_graph(A, b, c, result, problem_title):
    x = np.linspace(0, 10, 400)  # Define grid range
    plt.figure(figsize=(8, 6))

    # Plot constraints
    for i in range(len(A)):
        if A[i][1] != 0:  # Avoid division by zero
            y = (b[i] - A[i][0] * x) / A[i][1]
            plt.plot(x, y, label=f"Constraint {i+1}")
            plt.fill_between(x, 0, y, where=(y >= 0), alpha=0.2)

    # Mark the optimal solution
    if result.success:
        x_opt, y_opt = result.x
        plt.plot(x_opt, y_opt, 'ro', label='Optimal Solution')
        plt.annotate(f"({x_opt:.2f}, {y_opt:.2f})", (x_opt, y_opt), textcoords="offset points", xytext=(-15, 10), ha='center')

    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.xlim(0, 10)
    plt.ylim(0, 10)
    plt.xlabel('x (Product A)')
    plt.ylabel('y (Product B)')
    plt.title(problem_title)
    plt.legend()
    plt.grid()
    plt.show()

def solve_problem(c, A, b, bounds, title):
    result = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method='highs')
    print(f"{title} Solution:")
    print(result)
    plot_graph(A, b, c, result, title)
    return result


# Problem 1: Maximizing Profit for a Factory
c1 = [-3, -4]
A1 = [[2, 3], [1, 2]]
b1 = [12, 8]
bounds1 = [(0, None), (0, None)]
solve_problem(c1, A1, b1, bounds1, "Maximizing Profit for a Factory")

# Problem 2: Minimizing Cost for a Manufacturer
c2 = [2, 5]
A2 = [[1, 2], [2, 1]]
b2 = [6, 5]
bounds2 = [(0, None), (0, None)]
solve_problem(c2, A2, b2, bounds2, "Minimizing Cost for a Manufacturer")

# Problem 3: Maximizing Production with Multiple Resources
c3 = [-5, -4]
A3 = [[2, 1], [3, 2], [1, 2]]
b3 = [20, 30, 18]
bounds3 = [(0, None), (0, None)]
solve_problem(c3, A3, b3, bounds3, "Maximizing Production with Multiple Resources")

# Problem 4: Maximizing Revenue from Sales
c4 = [-4, -5]
A4 = [[1, 2], [1, 2]]
b4 = [20, 15]
bounds4 = [(0, None), (0, None)]
solve_problem(c4, A4, b4, bounds4, "Maximizing Revenue from Sales")

# Problem 5: Resource Allocation for Two Projects
c5 = [-8, -7]
A5 = [[3, 4], [2, 1]]
b5 = [12, 6]
bounds5 = [(0, None), (0, None)]
solve_problem(c5, A5, b5, bounds5, "Resource Allocation for Two Projects")

# Problem 6: Production Planning for a Bakery
c6 = [-5, -3]
A6 = [[1, 2], [3, 2]]
b6 = [8, 12]
bounds6 = [(0, None), (0, None)]
solve_problem(c6, A6, b6, bounds6, "Production Planning for a Bakery")

# Problem 7: Minimizing Cost for a Transport Company
c7 = [6, 7]
A7 = [[3, 4], [2, 1]]
b7 = [18, 10]
bounds7 = [(0, None), (0, None)]
solve_problem(c7, A7, b7, bounds7, "Minimizing Cost for a Transport Company")

# Problem 8: Maximizing Revenue from Two Products
c8 = [-10, -12]
A8 = [[4, 3], [1, 2], [3, 2]]
b8 = [30, 18, 24]
bounds8 = [(0, None), (0, None)]
solve_problem(c8, A8, b8, bounds8, "Maximizing Revenue from Two Products")

# Problem 9: Advertising Campaign Budget Allocation
c9 = [-500000, -400000]
A9 = [[4000, 3000], [2000, 2500], [1000, 1500]]
b9 = [5000, 4500, 3000]
bounds9 = [(0, None), (0, None)]
solve_problem(c9, A9, b9, bounds9, "Advertising Campaign Budget Allocation")

# Problem 10: Meal Planning for a School Cafeteria
c10 = [-2, -1]
A10 = [[2, 4], [3, 2], [1, 2]]
b10 = [12, 12, 8]
bounds10 = [(0, None), (0, None)]
solve_problem(c10, A10, b10, bounds10, "Meal Planning for a School Cafeteria")
# Out:
# Maximizing Profit for a Factory Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -18.0
#               x: [ 6.000e+00  0.000e+00]
#             nit: 1
#           lower:  residual: [ 6.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  5.000e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  2.000e+00]
#                  marginals: [-1.500e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Minimizing Cost for a Manufacturer Solution:
#        message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#        success: True
#         status: 0
#            fun: 0.0
#              x: [ 0.000e+00  0.000e+00]
#            nit: 0
#          lower:  residual: [ 0.000e+00  0.000e+00]
#                 marginals: [ 2.000e+00  5.000e+00]
#          upper:  residual: [       inf        inf]
#                 marginals: [ 0.000e+00  0.000e+00]
#          eqlin:  residual: []
#                 marginals: []
#        ineqlin:  residual: [ 6.000e+00  5.000e+00]
#                 marginals: [-0.000e+00 -0.000e+00]
# Maximizing Production with Multiple Resources Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -54.0
#               x: [ 6.000e+00  6.000e+00]
#             nit: 2
#           lower:  residual: [ 6.000e+00  6.000e+00]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 2.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.500e+00 -5.000e-01]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Maximizing Revenue from Sales Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -60.0
#               x: [ 1.500e+01  0.000e+00]
#             nit: 0
#           lower:  residual: [ 1.500e+01  0.000e+00]
#                  marginals: [ 0.000e+00  3.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 5.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -4.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Resource Allocation for Two Projects Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -27.6
#               x: [ 2.400e+00  1.200e+00]
#             nit: 2
#           lower:  residual: [ 2.400e+00  1.200e+00]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00]
#                  marginals: [-1.200e+00 -2.200e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Production Planning for a Bakery Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -20.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 1
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  3.333e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.667e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Minimizing Cost for a Transport Company Solution:
#        message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#        success: True
#         status: 0
#            fun: 0.0
#              x: [ 0.000e+00  0.000e+00]
#            nit: 0
#          lower:  residual: [ 0.000e+00  0.000e+00]
#                 marginals: [ 6.000e+00  7.000e+00]
#          upper:  residual: [       inf        inf]
#                 marginals: [ 0.000e+00  0.000e+00]
#          eqlin:  residual: []
#                 marginals: []
#        ineqlin:  residual: [ 1.800e+01  1.000e+01]
#                 marginals: [-0.000e+00 -0.000e+00]
# Maximizing Revenue from Two Products Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -112.80000000000001
#               x: [ 1.200e+00  8.400e+00]
#             nit: 2
#           lower:  residual: [ 1.200e+00  8.400e+00]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00  3.600e+00]
#                  marginals: [-1.600e+00 -3.600e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Advertising Campaign Budget Allocation Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -666666.6666666667
#               x: [ 0.000e+00  1.667e+00]
#             nit: 3
#           lower:  residual: [ 0.000e+00  1.667e+00]
#                  marginals: [ 3.333e+04  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  3.333e+02  5.000e+02]
#                  marginals: [-1.333e+02 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Meal Planning for a School Cafeteria Solution:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -8.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 2
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  3.333e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.000e+00  0.000e+00  4.000e+00]
#                  marginals: [-0.000e+00 -6.667e-01 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -8.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 2
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  3.333e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.000e+00  0.000e+00  4.000e+00]
#                  marginals: [-0.000e+00 -6.667e-01 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linprog
from itertools import combinations

def find_corner_points(A, b):
    """Calculate all corner points by solving for intersections of constraints."""
    num_constraints = len(A)
    points = []
    
    # Generate all combinations of 2 constraints
    for (i, j) in combinations(range(num_constraints), 2):
        A_subset = np.array([A[i], A[j]])
        b_subset = np.array([b[i], b[j]])
        
        try:
            # Solve for intersection
            point = np.linalg.solve(A_subset, b_subset)
            points.append(point)
        except np.linalg.LinAlgError:
            # Skip if the system of equations is not solvable
            continue
    
    return np.array(points)

def filter_feasible_points(points, A, b):
    """Filter corner points to only include those that satisfy all constraints."""
    feasible_points = []
    for point in points:
        if all(np.dot(A, point) <= b) and all(point >= 0):  # Satisfies all constraints and non-negativity
            feasible_points.append(point)
    return np.array(feasible_points)

def plot_graph(A, b, c, result, feasible_points, problem_title):
    """Plot constraints, feasible region, and optimal solution."""
    x = np.linspace(0, 10, 400)
    plt.figure(figsize=(8, 6))

    # Plot constraints
    for i in range(len(A)):
        if A[i][1] != 0:  # Avoid division by zero
            y = (b[i] - A[i][0] * x) / A[i][1]
            plt.plot(x, y, label=f"Constraint {i+1}")
            plt.fill_between(x, 0, y, where=(y >= 0), alpha=0.2)

    # Plot feasible points
    for point in feasible_points:
        plt.plot(point[0], point[1], 'go', label='Corner Point' if 'Corner Point' not in plt.gca().get_legend_handles_labels()[1] else "")

    # Mark the optimal solution
    if result.success:
        x_opt, y_opt = result.x
        plt.plot(x_opt, y_opt, 'ro', label='Optimal Solution')
        plt.annotate(f"({x_opt:.2f}, {y_opt:.2f})", (x_opt, y_opt), textcoords="offset points", xytext=(-15, 10), ha='center')

    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.xlim(0, 10)
    plt.ylim(0, 10)
    plt.xlabel('x (Product A)')
    plt.ylabel('y (Product B)')
    plt.title(problem_title)
    plt.legend()
    plt.grid()
    plt.show()

def solve_problem(c, A, b, bounds, title):
    """Solve the LP problem, find corner points, and visualize."""
    result = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method='highs')
    
    # Find all corner points
    corner_points = find_corner_points(A, b)
    feasible_points = filter_feasible_points(corner_points, A, b)
    
    print(f"\n{title}")
    print("Optimal Solution:", result)
    print("Feasible Corner Points:", feasible_points)
    
    plot_graph(A, b, c, result, feasible_points, title)
    return result

# Problem 1: Maximizing Profit for a Factory
c1 = [-3, -4]
A1 = [[2, 3], [1, 2]]
b1 = [12, 8]
bounds1 = [(0, None), (0, None)]
solve_problem(c1, A1, b1, bounds1, "Maximizing Profit for a Factory")

# Problem 2: Minimizing Cost for a Manufacturer
c2 = [2, 5]
A2 = [[1, 2], [2, 1]]
b2 = [6, 5]
bounds2 = [(0, None), (0, None)]
solve_problem(c2, A2, b2, bounds2, "Minimizing Cost for a Manufacturer")

# Problem 3: Maximizing Production with Multiple Resources
c3 = [-5, -4]
A3 = [[2, 1], [3, 2], [1, 2]]
b3 = [20, 30, 18]
bounds3 = [(0, None), (0, None)]
solve_problem(c3, A3, b3, bounds3, "Maximizing Production with Multiple Resources")

# Problem 4: Maximizing Revenue from Sales
c4 = [-4, -5]
A4 = [[1, 2], [1, 2]]
b4 = [20, 15]
bounds4 = [(0, None), (0, None)]
solve_problem(c4, A4, b4, bounds4, "Maximizing Revenue from Sales")

# Problem 5: Resource Allocation for Two Projects
c5 = [-8, -7]
A5 = [[3, 4], [2, 1]]
b5 = [12, 6]
bounds5 = [(0, None), (0, None)]
solve_problem(c5, A5, b5, bounds5, "Resource Allocation for Two Projects")

# Problem 6: Production Planning for a Bakery
c6 = [-5, -3]
A6 = [[1, 2], [3, 2]]
b6 = [8, 12]
bounds6 = [(0, None), (0, None)]
solve_problem(c6, A6, b6, bounds6, "Production Planning for a Bakery")

# Problem 7: Minimizing Cost for a Transport Company
c7 = [6, 7]
A7 = [[3, 4], [2, 1]]
b7 = [18, 10]
bounds7 = [(0, None), (0, None)]
solve_problem(c7, A7, b7, bounds7, "Minimizing Cost for a Transport Company")

# Problem 8: Maximizing Revenue from Two Products
c8 = [-10, -12]
A8 = [[4, 3], [1, 2], [3, 2]]
b8 = [30, 18, 24]
bounds8 = [(0, None), (0, None)]
solve_problem(c8, A8, b8, bounds8, "Maximizing Revenue from Two Products")

# Problem 9: Advertising Campaign Budget Allocation
c9 = [-500000, -400000]
A9 = [[4000, 3000], [2000, 2500], [1000, 1500]]
b9 = [5000, 4500, 3000]
bounds9 = [(0, None), (0, None)]
solve_problem(c9, A9, b9, bounds9, "Advertising Campaign Budget Allocation")

# Problem 10: Meal Planning for a School Cafeteria
c10 = [-2, -1]
A10 = [[2, 4], [3, 2], [1, 2]]
b10 = [12, 12, 8]
bounds10 = [(0, None), (0, None)]
solve_problem(c10, A10, b10, bounds10, "Meal Planning for a School Cafeteria")
# Out:
# Maximizing Profit for a Factory
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -18.0
#               x: [ 6.000e+00  0.000e+00]
#             nit: 1
#           lower:  residual: [ 6.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  5.000e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  2.000e+00]
#                  marginals: [-1.500e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: [[0. 4.]]
# Minimizing Cost for a Manufacturer
# Optimal Solution:        message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#        success: True
#         status: 0
#            fun: 0.0
#              x: [ 0.000e+00  0.000e+00]
#            nit: 0
#          lower:  residual: [ 0.000e+00  0.000e+00]
#                 marginals: [ 2.000e+00  5.000e+00]
#          upper:  residual: [       inf        inf]
#                 marginals: [ 0.000e+00  0.000e+00]
#          eqlin:  residual: []
#                 marginals: []
#        ineqlin:  residual: [ 6.000e+00  5.000e+00]
#                 marginals: [-0.000e+00 -0.000e+00]
# Feasible Corner Points: [[1.33333333 2.33333333]]
# Maximizing Production with Multiple Resources
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -54.0
#               x: [ 6.000e+00  6.000e+00]
#             nit: 2
#           lower:  residual: [ 6.000e+00  6.000e+00]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 2.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.500e+00 -5.000e-01]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: [[6. 6.]]
# Maximizing Revenue from Sales
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -60.0
#               x: [ 1.500e+01  0.000e+00]
#             nit: 0
#           lower:  residual: [ 1.500e+01  0.000e+00]
#                  marginals: [ 0.000e+00  3.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 5.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -4.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: []
# Resource Allocation for Two Projects
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -27.6
#               x: [ 2.400e+00  1.200e+00]
#             nit: 2
#           lower:  residual: [ 2.400e+00  1.200e+00]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00]
#                  marginals: [-1.200e+00 -2.200e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: [[2.4 1.2]]
# Production Planning for a Bakery
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -20.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 1
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  3.333e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.667e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: [[2. 3.]]
# Minimizing Cost for a Transport Company
# Optimal Solution:        message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#        success: True
#         status: 0
#            fun: 0.0
#              x: [ 0.000e+00  0.000e+00]
#            nit: 0
#          lower:  residual: [ 0.000e+00  0.000e+00]
#                 marginals: [ 6.000e+00  7.000e+00]
#          upper:  residual: [       inf        inf]
#                 marginals: [ 0.000e+00  0.000e+00]
#          eqlin:  residual: []
#                 marginals: []
#        ineqlin:  residual: [ 1.800e+01  1.000e+01]
#                 marginals: [-0.000e+00 -0.000e+00]
# Feasible Corner Points: [[4.4 1.2]]
# Maximizing Revenue from Two Products
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -112.80000000000001
#               x: [ 1.200e+00  8.400e+00]
#             nit: 2
#           lower:  residual: [ 1.200e+00  8.400e+00]
#                  marginals: [ 0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00  3.600e+00]
#                  marginals: [-1.600e+00 -3.600e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: [[1.2 8.4]]
# Advertising Campaign Budget Allocation
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -666666.6666666667
#               x: [ 0.000e+00  1.667e+00]
#             nit: 3
#           lower:  residual: [ 0.000e+00  1.667e+00]
#                  marginals: [ 3.333e+04  0.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  3.333e+02  5.000e+02]
#                  marginals: [-1.333e+02 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: []
# Meal Planning for a School Cafeteria
# Optimal Solution:         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -8.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 2
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  3.333e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.000e+00  0.000e+00  4.000e+00]
#                  marginals: [-0.000e+00 -6.667e-01 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Feasible Corner Points: [[3.  1.5]]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -8.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 2
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  3.333e-01]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.000e+00  0.000e+00  4.000e+00]
#                  marginals: [-0.000e+00 -6.667e-01 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
